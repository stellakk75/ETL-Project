# %%
# Import Libraries
import datetime as dt
import numpy as np
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
import psycopg2
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify

# %%
# Database Setup
connection = psycopg2.connect(user = "postgres",
                                  password = "Isla",
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "quotes_db")
db_string = "postgres://postgres:Islas@localhost:5432/quotes_db"
engine = connection.cursor()
db = create_engine(db_string)

# %%
# top10tags_df = pd.read_sql_query(
#                    ''' SELECT tag,count(*) FROM TAGS \
#                        GROUP BY tag \
#                        ORDER BY count(*) DESC LIMIT 10
#                    ''' , db
#                                     )

# %%
# top10tags_df.to_dict('split')['data'][0][0]
# Out:
# 'love'

# %%
# len(top10tags_df.to_dict('split')['data'])
# Out:
# 10

# %%
# i = 0
# cnt = 0
# tags_dict = {}
# t = []
# for i in range(len(top10tags_df.to_dict('split')['data'])):
#     top_dict = {}
#     tags = top10tags_df.to_dict('split')['data'][i][0]
#     cnt =  top10tags_df.to_dict('split')['data'][i][1]

#     data = {
#         'tags' : tags,
#         'quote_count' : cnt
#     }
#     t.append(data)

# %%
# t
# Out:
# [{'tags': 'love', 'quote_count': 14},
#  {'tags': 'inspirational', 'quote_count': 13},
#  {'tags': 'life', 'quote_count': 13},
#  {'tags': 'humor', 'quote_count': 12},
#  {'tags': 'books', 'quote_count': 11},
#  {'tags': 'reading', 'quote_count': 7},
#  {'tags': 'friendship', 'quote_count': 5},
#  {'tags': 'truth', 'quote_count': 4},
#  {'tags': 'friends', 'quote_count': 4},
#  {'tags': 'attributed-no-source', 'quote_count': 3}]

# %%
engine.execute("SELECT COUNT(*) FROM quotes;")
total_tags = engine.fetchone()  
total_tags
# Out:
# (100,)

# %%
quotes_all_df = pd.read_sql_query(
        '''SELECT quotes.quote_id,quotes.author_name,quotes.quote,tags.tag \
                    FROM quotes \
                    JOIN \
                    tags ON quotes.quote_id = tags.quote_id \
                    ORDER BY quotes.quote_id''',db
                                    )

# %%
quotes_all_df
# Out:
#      quote_id         author_name  \
# 0           1     Albert Einstein
# 1           1     Albert Einstein
# 2           1     Albert Einstein
# 3           1     Albert Einstein
# 4           2        J.K. Rowling
# ..        ...                 ...
# 227        97   Madeleine L'Engle
# 228        98          Mark Twain
# 229        99           Dr. Seuss
# 230       100  George R.R. Martin
# 231       100  George R.R. Martin
#
#                                                  quote            tag
# 0    “The world as we have created it is a process ...         change
# 1    “The world as we have created it is a process ...  deep-thoughts
# 2    “The world as we have created it is a process ...       thinking
# 3    “The world as we have created it is a process ...          world
# 4    “It is our choices, Harry, that show what we t...      abilities
# ..                                                 ...            ...
# ...

# %%
xx = quotes_all_df.groupby(['quote_id','author_name','quote']).tag.apply(list).reset_index()

# %%
xx
# Out:
# pandas.core.frame.DataFrame

# %%
xx.to_dict('split')['data']
# Out:
# [[1,
#   'Albert Einstein',
#   '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”by Albert Einstein(about)            Tags:            changedeep-thoughtsthinkingworld',
#   ['change', 'deep-thoughts', 'thinking', 'world']],
#  [2,
#   'J.K. Rowling',
#   '“It is our choices, Harry, that show what we truly are, far more than our abilities.”by J.K. Rowling(about)            Tags:            abilitieschoices',
#   ['abilities', 'choices']],
#  [3,
#   'Albert Einstein',
#   '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”by Albert Einstein(about)            Tags:            inspirationallifelivemiraclemiracles',
#   ['inspirational', 'life', 'live', 'miracle', 'miracles']],
#  [4,
#   'Jane Austen',
# ...

# %%
quotes_list = []
for i in range(len(xx.to_dict('split')['data'])):
        author_name = xx.to_dict('split')['data'][i][1]
        quote =  xx.to_dict('split')['data'][i][2]
        tags = xx.to_dict('split')['data'][i][3]

        data = {
            'text' : quote,
            'author name' : author_name,
            'tags' : tags
        }
        quotes_list.append(data)

# %%
quotes_list
# Out:
# [{'text': '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”by Albert Einstein(about)            Tags:            changedeep-thoughtsthinkingworld',
#   'author name': 'Albert Einstein',
#   'tags': ['change', 'deep-thoughts', 'thinking', 'world']},
#  {'text': '“It is our choices, Harry, that show what we truly are, far more than our abilities.”by J.K. Rowling(about)            Tags:            abilitieschoices',
#   'author name': 'J.K. Rowling',
#   'tags': ['abilities', 'choices']},
#  {'text': '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”by Albert Einstein(about)            Tags:            inspirationallifelivemiraclemiracles',
#   'author name': 'Albert Einstein',
#   'tags': ['inspirational', 'life', 'live', 'miracle', 'miracles']},
# ...

# %%
engine.execute("SELECT COUNT(*) FROM quotes;")
total_cnt = engine.fetchone()

# %%
total_cnt
# Out:
# (100,)

# %%
quotes_dict =[]
data = {
    'total' :total_cnt,
    'quotes':quotes_list
     }
quotes_dict.append(data)

# %%
quotes_dict
# Out:
# [{'total': (100,),
#   'quotes': [{'text': '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”by Albert Einstein(about)            Tags:            changedeep-thoughtsthinkingworld',
#     'author name': 'Albert Einstein',
#     'tags': ['change', 'deep-thoughts', 'thinking', 'world']},
#    {'text': '“It is our choices, Harry, that show what we truly are, far more than our abilities.”by J.K. Rowling(about)            Tags:            abilitieschoices',
#     'author name': 'J.K. Rowling',
#     'tags': ['abilities', 'choices']},
#    {'text': '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”by Albert Einstein(about)            Tags:            inspirationallifelivemiraclemiracles',
#     'author name': 'Albert Einstein',
#     'tags': ['inspirational', 'life', 'live', 'miracle', 'miracles']},
# ...

# %%
#Query to pull author quotes
author_quotes_df = pd.read_sql_query(
                        '''
                        SELECT author_name,quotes
                        FROM quotes
                        ORDER BY author_name  
                        '''
                        , db)

# %%
author_quotes_df
# Out:
#           author_name                                             quotes
# 0     Albert Einstein  (27,"Albert Einstein","“If you want your child...
# 1     Albert Einstein  (1,"Albert Einstein","“The world as we have cr...
# 2     Albert Einstein  (6,"Albert Einstein","“Try not to become a man...
# 3     Albert Einstein  (45,"Albert Einstein","“Life is like riding a ...
# 4     Albert Einstein  (3,"Albert Einstein","“There are only two ways...
# ..                ...                                                ...
# 95    Suzanne Collins  (62,"Suzanne Collins","“You don’t forget the f...
# 96    Terry Pratchett  (73,"Terry Pratchett","“The trouble with havin...
# 97   Thomas A. Edison  (8,"Thomas A. Edison","“I have not failed. I'v...
# 98        W.C. Fields  (78,"W.C. Fields","“I am free of all prejudice...
# 99  William Nicholson  (37,"William Nicholson","“We read to know we'r...
#
# [100 rows x 2 columns]

# %%
authors_all_df = pd.read_sql_query(
                '''SELECT author.author_name,author.dob AS born,
                          author.description,
	                     (SELECT COUNT(*) FROM quotes
		                  WHERE quotes.author_name = author.author_name) AS quote_count	
                          FROM author
                          ORDER BY 1
               ''',db
                                    )

# %%
authors_all_df.head(2)
# Out:
#             author_name            born  \
# 0       Albert Einstein  March 14, 1879
# 1  Alexandre Dumas fils   July 27, 1824
#
#                                          description  quote_count
# 0          In 1879, Albert Einstein was born in U...           10
# 1          Alexandre Dumas (son) was born in Pari...            1

# %%
yy = authors_all_df.to_dict('split')['data']

# %%
yy[0][0]
# Out:
# 'Albert Einstein'

# %%
yy[0][1]
# Out:
# 'March 14, 1879'

# %%
yy[0][2]
# Out:
# '        In 1879, Albert Einstein was born in Ulm, Germany. He completed his Ph.D. at the University of Zurich by 1909. His 1905 paper explaining the photoelectric effect, the basis of electronics, earned him the Nobel Prize in 1921. His first paper on Special Relativity Theory, also published in 1905, changed the world. After the rise of the Nazi party, Einstein made Princeton his permanent home, becoming a U.S. citizen in 1940. Einstein, a pacifist during World War I, stayed a firm proponent of social justice and responsibility. He chaired the Emergency Committee of Atomic Scientists, which organized to alert the public to the dangers of atomic warfare.At a symposium, he advised: "In their struggle for the ethical good, teachers of religion must have the stature to give up the doctrine of a personal God, that is, give up that source of fear and hope which in the past placed such vast power in the hands of priests. In their labors they will have to avail themselves of those forces w
# ...

# %%
yy[0][3]
# Out:
# 10

# %%
data = {
    'name': author_name,
    'description': description,
    'born': dob,
    'count': count,
    'quotes':[
                {'text' : quotes,
                 'tages': []}]'
}

# %%
print(yy[0][0], yy[0][1], yy[0][2], yy[0][3])
# Out:
# Albert Einstein March 14, 1879         In 1879, Albert Einstein was born in Ulm, Germany. He completed his Ph.D. at the University of Zurich by 1909. His 1905 paper explaining the photoelectric effect, the basis of electronics, earned him the Nobel Prize in 1921. His first paper on Special Relativity Theory, also published in 1905, changed the world. After the rise of the Nazi party, Einstein made Princeton his permanent home, becoming a U.S. citizen in 1940. Einstein, a pacifist during World War I, stayed a firm proponent of social justice and responsibility. He chaired the Emergency Committee of Atomic Scientists, which organized to alert the public to the dangers of atomic warfare.At a symposium, he advised: "In their struggle for the ethical good, teachers of religion must have the stature to give up the doctrine of a personal God, that is, give up that source of fear and hope which in the past placed such vast power in the hands of priests. In their labors they will have to avai
# ...

# %%
author_list = []
for i in range(len(authors_all_df.to_dict('split')['data'])):
        
        author_name = yy[i][0]
        born = yy[i][1]
        description =  yy[i][2]
        count = yy[i][3]

        data = {
            'born' : born,
            'name' : author_name,
            'description' : description,
            'count' : count
        }
        author_list.append(data)

# %%
# Pull tags and quote data
quotes_tag_df = pd.read_sql_query(
                '''
                SELECT quotes.quote_id,quotes.quote,tags.tag
                FROM tags
                JOIN
                     quotes
                ON quotes.quote_id = tags.quote_id
                ''',db
                                    )

# %%
zz = quotes_tag_df.to_dict('split')['data']
tags_zz = quotes_tag_df.groupby(['quote_id','quote']).tag.apply(list).reset_index()
tags_aa = tags_zz.to_dict('split')['data']

# %%
quote_tags = []
for i in range(len(tags_aa)):
        
        text = tags_aa[i][1]
        tags = tags_aa[i][2]

        data = {
            'text' : text,
            'tags' : tags
        }
        quote_tags.append(data)

# %%
authors_details = []

# %%
quotes_tag_df
# Out:
#      quote_id                                              quote  \
# 0           1  “The world as we have created it is a process ...
# 1           1  “The world as we have created it is a process ...
# 2           1  “The world as we have created it is a process ...
# 3           1  “The world as we have created it is a process ...
# 4           2  “It is our choices, Harry, that show what we t...
# ..        ...                                                ...
# 227        97  “You have to write the book that wants to be w...
# 228        98  “Never tell the truth to people who are not wo...
# 229        99  “A person's a person, no matter how small.”by ...
# 230       100  “... a mind needs books as a sword needs a whe...
# 231       100  “... a mind needs books as a sword needs a whe...
#
#                tag
# 0           change
# 1    deep-thoughts
# 2         thinking
# 3            world
# 4        abilities
# ..             ...
# 227        writing
# 228          truth
# ...

# %%
# Out:
#                author_name                born  \
# 0          Albert Einstein      March 14, 1879
# 1     Alexandre Dumas fils       July 27, 1824
# 2          Alfred Tennyson     August 06, 1809
# 3           Allen Saunders      April 24, 1899
# 4               André Gide   November 22, 1869
# 5                 Ayn Rand   February 02, 1905
# 6               Bob Marley   February 06, 1945
# 7               C.S. Lewis   November 29, 1898
# 8         Charles Bukowski     August 16, 1920
# 9        Charles M. Schulz   November 26, 1922
# 10           Douglas Adams      March 11, 1952
# 11               Dr. Seuss      March 02, 1904
# 12           E.E. Cummings    October 14, 1894
# 13       Eleanor Roosevelt    October 11, 1884
# 14             Elie Wiesel  September 30, 1928
# 15        Ernest Hemingway       July 21, 1899
# 16     Friedrich Nietzsche    October 15, 1844
# 17        Garrison Keillor     August 07, 1942
# 18     George Bernard Shaw       July 26, 1856
# ...

# %%
restaurant_review_frame.join(other=restaurant_ids_dataframe,on='business_id',how='left')

# %%
authors_all_df.join(quotes_tag_df,on=)
